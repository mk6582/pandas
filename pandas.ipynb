# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from pandas_profiling import ProfileReport

# %% [markdown]
# ## data type

# %%
series = pd.Series([" maruti "," Tata "," mahindra "])
series
# Out:
# 0       maruti
# 1         Tata
# 2     mahindra
# dtype: object

# %%
colors=pd.Series(["red","green","blue"])
colors
# Out:
# 0      red
# 1    green
# 2     blue
# dtype: object

# %% [markdown]
# ## data frame

# %%
car_data=pd.DataFrame({"car" : series,"colors" :colors})
car_data
# Out:
#           car colors
# 0     maruti     red
# 1       Tata   green
# 2   mahindra    blue

# %% [markdown]
# ## import data

# %%
car_sales = pd.read_csv("car_sales.csv")     # importing .csv files
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("Exported_car_sales.csv")  # exporting file after editing
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns=car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.describe()      ## statistical information
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info() ## (index + dtypes) information about data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_prices = pd.Series([3000,1500,111250])
car_prices.mean()
# Out:
# 38583.333333333336

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## View and selecting

# %%
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail(5)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
name = pd.Series(["manoj","kundan","sachin"])
name
# Out:
# 0     manoj
# 1    kundan
# 2    sachin
# dtype: object

# %%
name.loc[2]      # .loc for location of index
# Out:
# 'sachin'

# %%
name.loc[:3]
# Out:
# 0     manoj
# 1    kundan
# 2    sachin
# dtype: object

# %%
name.iloc[2]
# Out:
# 'sachin'

# %%
name.iloc[:3]
# Out:
# 0     manoj
# 1    kundan
# 2    sachin
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 car_sales["Price"].plot()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
car_sales["Price"]= car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)
car_sales["Price"]
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_10436\2817383694.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"]= car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int32

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv("car_sales_missing_data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace = True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna ( inplace = True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
seats = pd.Series([1,2,3,4,5])
car_sales["seats"]=seats

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  toyota  White         150043      4   400000    1.0
# 1   honda    Red          87899      4   500000    2.0
# 2  toyota   Blue          32549      3   700000    3.0
# 3     bmw  Black          11179      5  2200000    4.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales["seats"].fillna(5,inplace = True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  toyota  White         150043      4   400000    1.0
# 1   honda    Red          87899      4   500000    2.0
# 2  toyota   Blue          32549      3   700000    3.0
# 3     bmw  Black          11179      5  2200000    4.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
fuel_economy = pd.Series([11,8,11,10,8,9,7,8,8,10])
car_sales["fuel Economy"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel Economy
# 0  toyota  White         150043      4   400000    1.0            11
# 1   honda    Red          87899      4   500000    2.0             8
# 2  toyota   Blue          32549      3   700000    3.0            11
# 3     bmw  Black          11179      5  2200000    4.0            10
# 4  nissan  White         213095      4   350000    5.0             8
# 5  toyota  Green          99213      4   450000    5.0             9
# 6   honda   Blue          45698      4   750000    5.0             7
# 7   honda   Blue          54738      4   700000    5.0             8
# 8  toyota  White          60000      4   625000    5.0             8
# 9  nissan  White          31600      4   970000    5.0            10

# %%
car_sales["Fuel used"]=car_sales["Odometer (KM)"]/100 * car_sales["fuel Economy"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel Economy  \
# 0  toyota  White         150043      4   400000    1.0            11
# 1   honda    Red          87899      4   500000    2.0             8
# 2  toyota   Blue          32549      3   700000    3.0            11
# 3     bmw  Black          11179      5  2200000    4.0            10
# 4  nissan  White         213095      4   350000    5.0             8
# 5  toyota  Green          99213      4   450000    5.0             9
# 6   honda   Blue          45698      4   750000    5.0             7
# 7   honda   Blue          54738      4   700000    5.0             8
# 8  toyota  White          60000      4   625000    5.0             8
# 9  nissan  White          31600      4   970000    5.0            10
#
#    fuel used  Fuel used
# 0   16504.73   16504.73
# 1    7031.92    7031.92
# 2    3580.39    3580.39
# 3    1117.90    1117.90
# 4   17047.60   17047.60
# 5    8929.17    8929.17
# 6    3198.86    3198.86
# ...

# %%
car_sales.drop('fuel used', inplace=True, axis=1) ## to remove a columns
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel Economy  \
# 0  toyota  White         150043      4   400000    1.0            11
# 1   honda    Red          87899      4   500000    2.0             8
# 2  toyota   Blue          32549      3   700000    3.0            11
# 3     bmw  Black          11179      5  2200000    4.0            10
# 4  nissan  White         213095      4   350000    5.0             8
# 5  toyota  Green          99213      4   450000    5.0             9
# 6   honda   Blue          45698      4   750000    5.0             7
# 7   honda   Blue          54738      4   700000    5.0             8
# 8  toyota  White          60000      4   625000    5.0             8
# 9  nissan  White          31600      4   970000    5.0            10
#
#    Fuel used
# 0   16504.73
# 1    7031.92
# 2    3580.39
# 3    1117.90
# 4   17047.60
# 5    8929.17
# 6    3198.86
# 7    4379.04
# 8    4800.00
# 9    3160.00

# %%
car_sales_shuffle = car_sales.sample(frac = 1)     ## shuffle index values
car_sales_shuffle
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel Economy  \
# 0  toyota  White         150043      4   400000    1.0            11
# 4  nissan  White         213095      4   350000    5.0             8
# 6   honda   Blue          45698      4   750000    5.0             7
# 7   honda   Blue          54738      4   700000    5.0             8
# 5  toyota  Green          99213      4   450000    5.0             9
# 1   honda    Red          87899      4   500000    2.0             8
# 2  toyota   Blue          32549      3   700000    3.0            11
# 9  nissan  White          31600      4   970000    5.0            10
# 8  toyota  White          60000      4   625000    5.0             8
# 3     bmw  Black          11179      5  2200000    4.0            10
#
#    Fuel used
# 0   16504.73
# 4   17047.60
# 6    3198.86
# 7    4379.04
# 5    8929.17
# 1    7031.92
# 2    3580.39
# 9    3160.00
# 8    4800.00
# 3    1117.90

# %%
car_sales_shuffle.reset_index(drop = True,inplace = True)  
car_sales_shuffle
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel Economy  \
# 0  toyota  White         150043      4   400000    1.0            11
# 1  nissan  White         213095      4   350000    5.0             8
# 2   honda   Blue          45698      4   750000    5.0             7
# 3   honda   Blue          54738      4   700000    5.0             8
# 4  toyota  Green          99213      4   450000    5.0             9
# 5   honda    Red          87899      4   500000    2.0             8
# 6  toyota   Blue          32549      3   700000    3.0            11
# 7  nissan  White          31600      4   970000    5.0            10
# 8  toyota  White          60000      4   625000    5.0             8
# 9     bmw  Black          11179      5  2200000    4.0            10
#
#    Fuel used
# 0   16504.73
# 1   17047.60
# 2    3198.86
# 3    4379.04
# 4    8929.17
# 5    7031.92
# 6    3580.39
# 7    3160.00
# 8    4800.00
# 9    1117.90
